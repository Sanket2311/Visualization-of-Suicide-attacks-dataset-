# %%
import numpy as np
import pandas as pd
import seaborn as sns
import chardet

# %%
import os
import matplotlib.pyplot as plt
print(os.listdir('E:\ML_PY\Githubprojects\Pakistan'))
# Out:
# ['PakistanSuicideAttacks1.csv', 'PakistanSuicideAttacks2.csv']

# %%
with open("E:\ML_PY\Githubprojects\Pakistan/PakistanSuicideAttacks1.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
data1 = pd.read_csv('E:\ML_PY\Githubprojects\Pakistan/PakistanSuicideAttacks1.csv', encoding='Windows-1252')

# %%
data2 = pd.read_csv('E:\ML_PY\Githubprojects\Pakistan/PakistanSuicideAttacks2.csv', encoding='Windows-1252')

# %%
data1
# Out:
#       S#                       Date                   Islamic Date  \
# 0      1    Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1      2     Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2      3       Wednesday-May 8-2002              25 safar 1423 A.H
# 3      4        Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4      5         Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# 5      6  Thursday-December 25-2003      2 Thw al-Qi`dah 1424 A.H.
# 6      7  Saturday-February 28-2004            8 MuHarram 1425 A.H
# 7      8          Friday-May 7-2004      18 Raby` al-awal 1425 A.H
# 8      9         Monday-May 31-2004                            NaN
# 9     10       Thursday-June 3-2004    15 Raby` al-THaany 1425 A.H
# 10    11     Wednesday-July 28-2004  11 Jumaada al-THaany 1425 A.H
# 11    12        Friday-July 30-2004  13 Jumaada al-THaany 1425 A.H
# 12    13      Friday-October 1-2004           17 SHa`baan 1425 A.H
# 13    14     Sunday-October 10-2004          26 SHa`baan 1425 A.H.
# 14    15     Saturday-March 19-2005               9 safar 1426 A.H
# 15    16     Thursday-April 28-2005      19 Raby` al-awal 1426 A.H
# 16    17         Friday-May 27-2005    19 Raby` al-THaany 1426 A.H
# 17    18         Monday-May 30-2005    22 Raby` al-THaany 1426 A.H
# 18    19   Thursday-February 9-2006           10 MuHarram 1427 A.H
# 19    20      Thursday-March 2-2006              2 safar 1427 A.H.
# 20    21    Wednesday-April 12-2006      14 Raby` al-awal 1427 A.H
# 21    22         Friday-June 2-2006     6 Jumaada al-awal 1427 A.H
# 22    23        Monday-June 26-2006    30 Jumaada al-awal 1427 A.H
# 23    24       Sunday-August 6-2006              12 Rajab 1427 A.H
# 24    25  Wednesday-November 8-2006            17 SHawwal 1427 A.H
# 25    26    Friday-November 17-2006           26 SHawwal 1427 A.H.
# 26    27     Sunday-December 3-2006     12 Thw al-Qi`dah 1427 A.H.
# 27    28     Monday-January 22-2007            3 MuHarram 1428 A.H
# 28    29     Friday-January 26-2007            7 MuHarram 1428 A.H
# 29    30   Saturday-January 27-2007            8 MuHarram 1428 A.H
# ..   ...                        ...                            ...
# 462  463       Saturday-Feb 06-2016                            NaN
# 463  464       Saturday-Mar 07-2016                            NaN
# 464  465         Sunday-Mar 27-2016                            NaN
# 465  466       Saturday-Apr 16-2016              8 Rajab 1437 A.H.
# 466  467        Tuesday-Apr 19-2016             10 Rajab 1437 A.H.
# 467  468         Monday-May 30-2016            22 Shaban 1437 A.H.
# 468  469         Monday-Aug 08-2016             05 Zeqad 1437 A.H.
# 469  470         Friday-Sep 02-2016             29 Zeqad 1437 A.H.
# 470  471        Tuesday-Sep 13-2016            10 Zilhaj 1437 A.H.
# 471  472         Friday-Sep 16-2016            13 Zilhaj 1437 A.H.
# 472  473        Tuesday-Oct-25-2016          23 MuHarram 1438 A.H.
# 473  474       Saturday-Nov-12-2016             11 safar 1438 A.H.
# 474  475       Saturday-Nov-26-2016             25 safar 1438 A.H.
# 475  476         Tuesday-Feb-7-2017   09 Jamadi-ul-Awal 1438 A.H.
# 476  477         Monday-Feb-13-2017    16 Jumada al-awwal 1438 A.H
# 477  478      Wednesday-Feb-15-2017    19 Jumada al-awwal 1438 A.H
# 478  479      Wednesday-Feb-15-2017    19 Jumada al-awwal 1438 A.H
# 479  480      Wednesday-Feb-15-2017    19 Jumada al-awwal 1438 A.H
# 480  481       Thursday-Feb-16-2017    20 Jumada al-awwal 1438 A.H
# 481  482        Tuesday-Feb-21-2017    25 Jumada al-awwal 1438 A.H
# 482  483    Wednesday-April-05-2017              08 Rajab 1438 A.H
# 483  484         Friday-May-12-2017             15 Shaban 1438 A.H
# 484  485       Saturday-May-20-2017             23 Shaban 1438 A.H
# 485  486        Friday-June-23-2017          27 RamaDHaan 1432 A.H
# 486  487        Monday-July-10-2017            16 SHawwal 1432 A.H
# 487  488        Monday-July-17-2017            22 Shawaal 1432 A.H
# 488  489        Monday-July-17-2017            22 Shawaal 1432 A.H
# 489  490        Monday-July-24-2017            29 Shawaal 1432 A.H
# 490  491    Saturday-August-12-2017                            NaN
# 491  492   Thursday-October-05-2017                            NaN
#
#     Blast Day Type                        Holiday Type                   Time  \
# 0          Holiday                             Weekend                    NaN
# 1      Working Day                                 NaN                    NaN
# 2      Working Day                                 NaN                7:45 AM
# 3      Working Day                                 NaN            11:10:00 AM
# 4      Working Day                                 NaN                    NaN
# 5          Holiday  Christmas/birthday of Quaid-e-Azam  1:40:00 PM/1:42:00 PM
# 6      Working Day                                 NaN                    NaN
# 7      Working Day                                 NaN     1:20:00/1:17:00 PM
# 8      Working Day                                 NaN                evening
# 9      Working Day                                 NaN                    NaN
# 10     Working Day                                 NaN                8:50:PM
# 11     Working Day                                 NaN                7:20 PM
# 12     Working Day                                 NaN        1:27 PM/1:25 PM
# 13         Holiday                             Weekend     5:55:00/6:40:00 PM
# 14     Working Day                                 NaN      11.45PM /10.30 pm
# 15     Working Day                                 NaN                    NaN
# 16     Working Day                                 NaN            11:00:00 AM
# 17     Working Day                                 NaN                evening
# 18         Holiday                              Ashura             9:35:00 AM
# 19     Working Day                                 NaN             9:00:00 AM
# 20         Holiday                   Eid Milad un-Nabi                7.00 pm
# 21     Working Day                                 NaN               10.30 am
# 22     Working Day                                 NaN             3:30:00 PM
# 23         Holiday                             Weekend                8.00 am
# 24     Working Day                                 NaN                 8.30am
# 25     Working Day                                 NaN         7.30 am/7:15AM
# 26         Holiday                             Weekend                    NaN
# 27     Working Day                                 NaN            10:30:00 AM
# 28     Working Day                                 NaN             2:37:00 PM
# 29     Working Day                                 NaN             8:40:00 PM
# ..             ...                                 ...                    ...
# 462    Working Day                                 NaN                    NaN
# 463    Working Day                                 NaN                    NaN
# 464        Holiday                                 NaN                    NaN
# 465    Working Day                                 NaN                    NaN
# 466    Working Day                                 NaN                    NaN
# 467    Working Day                                 NaN                    NaN
# 468    Working Day                                 NaN                    NaN
# 469    Working Day                                 NaN                5:50 AM
# 470        Holiday                 Eid ul Azha Holiday                7:30 AM
# 471    Working Day                                 NaN                1:30 PM
# 472    Working Day                                 NaN                12:00am
# 473        Weekend                                 NaN                6:00 PM
# 474        Weekend                                 NaN                6:00 AM
# 475    Working Day                                 NaN                5:00 AM
# 476    Working Day                                 NaN                6:00 PM
# 477    Working Day                                 NaN                8:00 AM
# 478    Working Day                                 NaN                3:30 PM
# 479    Working Day                                 NaN                9:00 AM
# 480    Working Day                                 NaN                6:00 PM
# 481    Working Day                                 NaN                9:00 AM
# 482    Working Day                                 NaN                7:15 AM
# 483    Working Day                                 NaN                 2:30PM
# 484        Weekend                                 NaN                    NaN
# 485    Working Day                                 NaN                 1:30PM
# 486    Working Day                                 NaN                11:43AM
# 487    Working Day                                 NaN                    NaN
# 488    Working Day                                 NaN                    NaN
# 489    Working Day                                 NaN                 3:55pm
# 490        Weekend                                 NaN                 5:00PM
# 491            NaN                                 NaN                    NaN
#
#                            City   Latitude   Longitude     Province  ...  \
# 0                     Islamabad  33.718000     73.0718      Capital  ...
# 1                       Karachi  24.991800     66.9911        Sindh  ...
# 2                      Karachi   24.991800     66.9911        Sindh  ...
# 3                       Karachi  24.991800     66.9911        Sindh  ...
# 4                        Quetta  30.209500     67.0182  Baluchistan  ...
# 5                    Rawalpindi  33.605800     73.0437       Punjab  ...
# 6                    Rawalpindi  33.605800     73.0437       Punjab  ...
# 7                      Karachi   24.991800     66.9911        Sindh  ...
# 8                      Karachi   24.991800     66.9911        Sindh  ...
# 9              North waziristan  32.974600     70.1456         FATA  ...
# 10                        Kohat  33.583300     71.4333          KPK  ...
# 11                      Attock   33.764500     72.3667       Punjab  ...
# 12                      Sialkot  32.497200     74.5361       Punjab  ...
# 13                      Lahore   31.545100     74.3407       Punjab  ...
# 14                       Quetta  30.209500     67.0182  Baluchistan  ...
# 15                         Swat  35.222700     72.4258          KPK  ...
# 16                    Islamabad  33.718000     73.0718      Capital  ...
# 17                     Karachi   24.991800     66.9911        Sindh  ...
# 18                        Hangu  33.535100     71.0713          KPK  ...
# 19                      Karachi  24.991800     66.9911        Sindh  ...
# 20                     Karachi   24.991800     66.9911        Sindh  ...
# 21                        Bannu  32.986100     70.6042          KPK  ...
# 22             North Waziristan  32.974600     70.1456         FATA  ...
# 23                      Lasbela  25.837700     66.5224  Baluchistan  ...
# 24                    Malakand   34.503000     71.9046          KPK  ...
# 25                     Peshawar  34.004300     71.5448          KPK  ...
# 26                        Bannu  32.986100     70.6042          KPK  ...
# 27             North Waziristan  32.974600     70.1456         FATA  ...
# 28                    Islamabad  33.718000     73.0718      Capital  ...
# 29                    Peshawar   34.004300     71.5448          KPK  ...
# ..                          ...        ...         ...          ...  ...
# 462                      Quetta  30.199805   67.010157  Balochistan  ...
# 463         Shabqadar-Charsadda  34.149433   71.742781          KPK  ...
# 464                      Lahore  31.512930    74.28899       Punjab  ...
# 465               Khyber Agency  34.047839    71.28436         FATA  ...
# 466                      Mardan  34.207854   72.049453          KPK  ...
# 467                      Mardan  34.195682   72.037771          KPK  ...
# 468                      Quetta  30.194225   67.008822  Balochistan  ...
# 469                      Mardan  34.195776   72.036565          KPK  ...
# 470                   Shikarpur  28.002718   68.730383        Sindh  ...
# 471             Mohmand Agency   34.400331   71.560424         FATA  ...
# 472                      Quetta  30.142830    66.98195  Balochistan  ...
# 473                     Khuzdar  25.776775    67.02239  Balochistan  ...
# 474              Mohmand Agency  34.325826   71.398789         FATA  ...
# 475                       Bannu  32.949814    70.60908          KPK  ...
# 476                      Lahore  31.555382   74.331873       Punjab  ...
# 477  Ghallanai, Mohmand Agency   34.500000   71.333333         FATA  ...
# 478                   Hayatabad  33.986111   71.456944          KPK  ...
# 479   Mosal Kor, Mohmand Agency  34.553808   71.434141         FATA  ...
# 480                 Sehwan town  26.419314   67.859373        Sindh  ...
# 481   Tangi, Charsadda District  34.300000   71.653889          KPK  ...
# 482                      Lahore  31.463017   74.435675       Punjab  ...
# 483                      Quetta  29.800833   66.848056  Baluchistan  ...
# 484                       Kohat  33.387520   71.340408          KPK  ...
# 485                      Quetta  33.884230    70.10878  Balochistan  ...
# 486                      Chaman  30.909830   66.452402  Balochistan  ...
# 487                    Peshawar  34.015000     71.5805          KPK  ...
# 488                    Peshawar  34.015000     71.5805          KPK  ...
# 489                      Lahore  31.500875    74.33312       Punjab  ...
# 490                      Quetta  30.203658   67.004469  Balochistan  ...
# 491                      Quetta  28.571051   67.496895  Balochistan  ...
#
#     Targeted Sect if any Killed Min Killed Max Injured Min Injured Max  \
# 0                   None       14.0       15.0         NaN          60
# 1                   None        NaN        3.0         NaN           3
# 2              Christian       13.0       15.0        20.0          40
# 3              Christian        NaN       12.0         NaN          51
# 4                 Shiite       44.0       47.0         NaN          65
# 5                   None       16.0       18.0         NaN          50
# 6                 shiite        NaN        1.0         3.0           4
# 7                 shiite       14.0       15.0        96.0         200
# 8                 Shiite       16.0       18.0         NaN          35
# 9                   None        NaN        2.0         NaN           2
# 10                  None        2.0        3.0         NaN           3
# 11                  None        NaN        7.0        44.0          70
# 12                shiite       25.0       31.0        50.0          75
# 13                shiite        4.0        5.0         6.0          10
# 14                Shiite       25.0       50.0         8.0         100
# 15                  None        NaN        2.0         NaN         NaN
# 16          Shiite/sunni       20.0       25.0        82.0         100
# 17                shiite        5.0        6.0        19.0          30
# 18                Shiite       37.0       40.0        90.0         NaN
# 19             Christian        4.0        5.0        30.0          54
# 20                 Sunni       47.0       57.0         NaN         100
# 21                  None        6.0        7.0         7.0           8
# 22                  None        6.0        7.0         NaN          26
# 23                  None        NaN        1.0         NaN           0
# 24                  None       40.0       42.0        20.0          39
# 25                  None        NaN        1.0         NaN           2
# 26                  None        NaN        1.0         NaN           1
# 27                  None        4.0        5.0        23.0          25
# 28                  None        1.0        2.0         5.0           7
# 29                shiite       13.0       15.0        30.0          60
# ..                   ...        ...        ...         ...         ...
# 462                 None        9.0       11.0        30.0          35
# 463                 None       10.0       20.0        27.0          31
# 464            Christian       70.0       72.0       233.0         300
# 465                 None        2.0        2.0         0.0           0
# 466                 None        1.0        1.0        10.0          18
# 467                 None        1.0        1.0        12.0          15
# 468                 None       70.0       70.0       112.0         120
# 469                 None       13.0       14.0        52.0          60
# 470               Shiite        0.0        0.0        10.0          13
# 471                  NaN       16.0       36.0        22.0         NaN
# 472                  NaN       58.0       61.0       100.0         165
# 473                 None       45.0       52.0       100.0         100
# 474                 None        2.0        2.0        14.0          14
# 475                 None        0.0        0.0         2.0           2
# 476                 None       14.0       18.0        83.0          90
# 477                 None        5.0        8.0         0.0           3
# 478                 None        1.0        1.0         4.0          18
# 479                 None        1.0        1.0         0.0           0
# 480               shiite       70.0       72.0       150.0         200
# 481                 None        6.0        7.0        15.0          20
# 482                 None        6.0        7.0        19.0          22
# 483                 None       25.0       28.0        35.0          37
# 484                 None        1.0        4.0         0.0           0
# 485               Shiite       30.0       85.0       100.0        100+
# 486                 None        1.0        3.0         1.0          11
# 487                 None        1.0        2.0         1.0           7
# 488                 None        1.0        1.0         1.0           1
# 489                  NaN       26.0       27.0        56.0          56
# 490                 None       15.0       15.0        40.0          40
# 491                  NaN       21.0       22.0        25.0         NaN
#
#     No. of Suicide Blasts Explosive Weight (max)  \
# 0                     2.0                    NaN
# 1                     1.0                    NaN
# 2                     1.0                 2.5 Kg
# 3                     1.0                    NaN
# 4                     1.0                    NaN
# 5                     2.0       30kg in each car
# 6                     1.0                    NaN
# 7                     1.0                    2kg
# 8                     1.0                    NaN
# 9                     1.0                    NaN
# 10                    2.0                    NaN
# 11                    1.0                    NaN
# 12                    1.0                    NaN
# 13                    1.0                    NaN
# 14                    1.0                    NaN
# 15                    1.0                    NaN
# 16                    1.0                    NaN
# 17                    1.0                    NaN
# 18                    1.0                    NaN
# 19                    1.0               10-15 kg
# 20                    1.0                   5 kg
# 21                    1.0                    NaN
# 22                    1.0                    NaN
# 23                    1.0                    NaN
# 24                    1.0                    NaN
# 25                    1.0                    NaN
# 26                    1.0                    NaN
# 27                    1.0                    NaN
# 28                    1.0                    NaN
# 29                    1.0                    NaN
# ..                    ...                    ...
# 462                   1.0                 8-10KG
# 463                   1.0                    NaN
# 464                   1.0                 8-10KG
# 465                   1.0                    NaN
# 466                   1.0                 8-10KG
# 467                   1.0                 8-10KG
# 468                   NaN                    8KG
# 469                   1.0                    6KG
# 470                   NaN                    NaN
# 471                   1.0                    NaN
# 472                   2.0                8-10 KG
# 473                   1.0                    NaN
# 474                   4.0                    NaN
# 475                   1.0                  20 KG
# 476                   1.0                    NaN
# 477                   1.0                    NaN
# 478                   1.0                  15 KG
# 479                   1.0                    NaN
# 480                   1.0                    NaN
# 481                   2.0                    NaN
# 482                   NaN                    NaN
# 483                   1.0                    NaN
# 484                   NaN                    NaN
# 485                   3.0                   75KG
# 486                   1.0                    NaN
# 487                   1.0                    NaN
# 488                   1.0                    NaN
# 489                   1.0                    NaN
# 490                   1.0                   25KG
# 491                   1.0                    NaN
#
#                                         Hospital Names  Temperature(C)  \
# 0                                                  NaN          15.835
# 1                                                  NaN          23.770
# 2    1.Jinnah Postgraduate Medical Center 2. Civil ...          31.460
# 3                                                  NaN          31.430
# 4    1.CMH Quetta \n2.Civil Hospital 3. Boland Medi...          33.120
# 5                  1.District headquarters \nHospital            9.445
# 6                                                  NaN          15.275
# 7                                      Civil hospital           33.860
# 8    Civil hospital-Liaquat National hospital-Jinna...          31.605
# 9                                                  NaN          27.180
# 10                                           CMH Kohat          32.430
# 11   1.District Headquarters hospital-rwp 2.PIMS Ho...          26.665
# 12   Allama Iqbal Memorial DHQ Hospital-Sardar Begu...          27.510
# 13                                      Mayo Hospital           24.390
# 14                                                 NaN          16.500
# 15                                                 NaN          19.935
# 16   1. PIMS 2.Polyclinic 3.CDA Hospital 4.federal ...          27.160
# 17                           1. Patel Hospital 2. JMPC          31.945
# 18                                     Hangu Hospital           15.495
# 19                                                 NaN          25.300
# 20   1. Liaquat National Hospital 2. Civil Hospital...          28.415
# 21           1. Combined Military 2. Hospital Peshawar          26.125
# 22                                                 NaN          28.610
# 23                                                 NaN          27.500
# 24                      1. CMH Mardan\n2. CMH Peshawar          19.205
# 25                                                 NaN          17.275
# 26                                                 NaN           4.705
# 27                                                 NaN           2.325
# 28                             1.poly Clinic Hospital           16.300
# 29                            1.Lady Reading hospital           15.165
# ..                                                 ...             ...
# 462                        Civil Hospital Quetta- CMH            9.945
# 463                              Lady Reading Hospital          16.715
# 464  Jinnah Hospital,Sheikh Zaid Hospital,Services ...          22.565
# 465                                                NaN          25.405
# 466                                                NaN          23.105
# 467                          Mardan district hospital.          30.020
# 468                                                NaN          29.585
# 469                                                NaN          27.805
# 470                                                NaN          31.945
# 471  District Headquarters Hospital (DHQ) Bajaur Ag...          28.680
# 472                                                NaN          14.545
# 473  Hub, Khuzdar, Lasbella and Civil Hospital in K...             NaN
# 474                                                NaN          17.630
# 475                                 DHQ Hospital Bannu          19.000
# 476        1. Mayo Hospital 2.  Sir Ganga Ram Hospital          16.255
# 477                              Lady Reading Hospital          11.115
# 478                          Hayatabad Medical Complex          16.630
# 479                                                NaN             NaN
# 480  1. Sehwan Taluka Hospital 2. Combined Military...          23.710
# 481                              Lady Reading Hospital          11.180
# 482  Combined Military Hospital (CMH), General Hosp...          29.000
# 483                                                NaN          44.000
# 484                                                NaN          37.000
# 485                                                NaN          36.000
# 486                                                NaN          38.000
# 487                                                NaN          37.000
# 488                                                NaN          37.000
# 489  Jinnah Hospital, General Hospital, Ittefaq Hos...          32.000
# 490                                                NaN          29.000
# 491  Larkana Hospital, Gandawah District Headquarte...          27.800
#
#      Temperature(F)
# 0            60.503
# 1            74.786
# 2            88.628
# 3            88.574
# 4            91.616
# 5            49.001
# 6            59.495
# 7            92.948
# 8            88.889
# 9            80.924
# 10           90.374
# 11           79.997
# 12           81.518
# 13           75.902
# 14           61.700
# 15           67.883
# 16           80.888
# 17           89.501
# 18           59.891
# 19           77.540
# 20           83.147
# 21           79.025
# 22           83.498
# 23           81.500
# 24           66.569
# 25           63.095
# 26           40.469
# 27           36.185
# 28           61.340
# 29           59.297
# ..              ...
# 462          49.901
# 463          62.087
# 464          72.617
# 465          77.729
# 466          73.589
# 467          86.036
# 468          85.253
# 469          82.049
# 470          89.501
# 471          83.624
# 472          58.181
# 473             NaN
# 474          63.734
# 475             NaN
# 476          61.259
# 477          52.007
# 478          61.934
# 479             NaN
# 480          74.678
# 481          52.124
# 482          84.200
# 483         111.000
# 484          99.000
# 485          97.000
# 486         100.000
# 487          98.000
# 488          98.000
# 489          88.000
# 490             NaN
# 491          81.000
#
# [492 rows x 26 columns]

# %%
data1.columns
# Out:
# Index(['S#', 'Date', 'Islamic Date', 'Blast Day Type', 'Holiday Type', 'Time',
#        'City', 'Latitude', 'Longitude', 'Province', 'Location',
#        'Location Category', 'Location Sensitivity', 'Open/Closed Space',
#        'Influencing Event/Event', 'Target Type', 'Targeted Sect if any',
#        'Killed Min', 'Killed Max', 'Injured Min', 'Injured Max',
#        'No. of Suicide Blasts', 'Explosive Weight (max)', 'Hospital Names',
#        'Temperature(C)', 'Temperature(F)'],
#       dtype='object')

# %%
data1.shape
# Out:
# (492, 26)

# %%
data1.describe()
# Out:
#                S#    Latitude  Killed Min  Killed Max  Injured Min  \
# count  492.000000  490.000000  346.000000   476.00000   361.000000
# mean   246.500000   32.621874   14.855491    15.30042    31.601108
# std    142.172431    2.477845   17.659154    20.32867    38.762832
# min      1.000000   24.879503    0.000000     0.00000     0.000000
# 25%    123.750000   31.823800    3.000000     3.00000     7.000000
# 50%    246.500000   33.583300    8.000000     8.00000    20.000000
# 75%    369.250000   34.004300   20.750000    19.00000    40.000000
# max    492.000000   35.383300  125.000000   148.00000   320.000000
#
#        No. of Suicide Blasts  Temperature(C)  Temperature(F)
# count             410.000000      487.000000      485.000000
# mean                1.117073       21.075554       69.906373
# std                 0.396749        8.390859       15.108953
# min                 1.000000       -2.370000       27.734000
# 25%                 1.000000       14.617500       58.253000
# 50%                 1.000000       21.295000       70.331000
# 75%                 1.000000       28.115000       82.499000
# max                 4.000000       44.000000      111.000000

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 26 columns):
# S#                         492 non-null int64
# Date                       492 non-null object
# Islamic Date               336 non-null object
# Blast Day Type             481 non-null object
# Holiday Type               72 non-null object
# Time                       281 non-null object
# City                       492 non-null object
# Latitude                   490 non-null float64
# Longitude                  490 non-null object
# Province                   492 non-null object
# Location                   489 non-null object
# Location Category          457 non-null object
# Location Sensitivity       456 non-null object
# Open/Closed Space          457 non-null object
# Influencing Event/Event    187 non-null object
# Target Type                466 non-null object
# Targeted Sect if any       443 non-null object
# Killed Min                 346 non-null float64
# Killed Max                 476 non-null float64
# Injured Min                361 non-null float64
# Injured Max                460 non-null object
# No. of Suicide Blasts      410 non-null float64
# Explosive Weight (max)     169 non-null object
# Hospital Names             294 non-null object
# Temperature(C)             487 non-null float64
# Temperature(F)             485 non-null float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 100.0+ KB

# %%
data2.shape
# Out:
# (496, 26)

# %%
data2.columns
# Out:
# Index(['S#', 'Date', 'Islamic Date', 'Blast Day Type', 'Holiday Type', 'Time',
#        'City', 'Latitude', 'Longitude', 'Province', 'Location',
#        'Location Category', 'Location Sensitivity', 'Open/Closed Space',
#        'Influencing Event/Event', 'Target Type', 'Targeted Sect if any',
#        'Killed Min', 'Killed Max', 'Injured Min', 'Injured Max',
#        'No. of Suicide Blasts', 'Explosive Weight (max)', 'Hospital Names',
#        'Temperature(C)', 'Temperature(F)'],
#       dtype='object')

# %%
data= pd.concat([data1,data2])

# %%
data.shape
# Out:
# (988, 26)

# %%
data
# Out:
#       S#                       Date                   Islamic Date  \
# 0      1    Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1      2     Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2      3       Wednesday-May 8-2002              25 safar 1423 A.H
# 3      4        Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4      5         Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# 5      6  Thursday-December 25-2003      2 Thw al-Qi`dah 1424 A.H.
# 6      7  Saturday-February 28-2004            8 MuHarram 1425 A.H
# 7      8          Friday-May 7-2004      18 Raby` al-awal 1425 A.H
# 8      9         Monday-May 31-2004                            NaN
# 9     10       Thursday-June 3-2004    15 Raby` al-THaany 1425 A.H
# 10    11     Wednesday-July 28-2004  11 Jumaada al-THaany 1425 A.H
# 11    12        Friday-July 30-2004  13 Jumaada al-THaany 1425 A.H
# 12    13      Friday-October 1-2004           17 SHa`baan 1425 A.H
# 13    14     Sunday-October 10-2004          26 SHa`baan 1425 A.H.
# 14    15     Saturday-March 19-2005               9 safar 1426 A.H
# 15    16     Thursday-April 28-2005      19 Raby` al-awal 1426 A.H
# 16    17         Friday-May 27-2005    19 Raby` al-THaany 1426 A.H
# 17    18         Monday-May 30-2005    22 Raby` al-THaany 1426 A.H
# 18    19   Thursday-February 9-2006           10 MuHarram 1427 A.H
# 19    20      Thursday-March 2-2006              2 safar 1427 A.H.
# 20    21    Wednesday-April 12-2006      14 Raby` al-awal 1427 A.H
# 21    22         Friday-June 2-2006     6 Jumaada al-awal 1427 A.H
# 22    23        Monday-June 26-2006    30 Jumaada al-awal 1427 A.H
# 23    24       Sunday-August 6-2006              12 Rajab 1427 A.H
# 24    25  Wednesday-November 8-2006            17 SHawwal 1427 A.H
# 25    26    Friday-November 17-2006           26 SHawwal 1427 A.H.
# 26    27     Sunday-December 3-2006     12 Thw al-Qi`dah 1427 A.H.
# 27    28     Monday-January 22-2007            3 MuHarram 1428 A.H
# 28    29     Friday-January 26-2007            7 MuHarram 1428 A.H
# 29    30   Saturday-January 27-2007            8 MuHarram 1428 A.H
# ..   ...                        ...                            ...
# 466  467        Tuesday-Apr 19-2016             10 Rajab 1437 A.H.
# 467  468         Monday-May 30-2016            22 Shaban 1437 A.H.
# 468  469         Monday-Aug 08-2016             05 Zeqad 1437 A.H.
# 469  470         Friday-Sep 02-2016             29 Zeqad 1437 A.H.
# 470  471        Tuesday-Sep 13-2016            10 Zilhaj 1437 A.H.
# 471  472         Friday-Sep 16-2016            13 Zilhaj 1437 A.H.
# 472  473        Tuesday-Oct-25-2016          23 MuHarram 1438 A.H.
# 473  474       Saturday-Nov-12-2016             11 safar 1438 A.H.
# 474  475       Saturday-Nov-26-2016             25 safar 1438 A.H.
# 475  476         Tuesday-Feb-7-2017   09 Jamadi-ul-Awal 1438 A.H.
# 476  477         Monday-Feb-13-2017    16 Jumada al-awwal 1438 A.H
# 477  478      Wednesday-Feb-15-2017    19 Jumada al-awwal 1438 A.H
# 478  479      Wednesday-Feb-15-2017    19 Jumada al-awwal 1438 A.H
# 479  480      Wednesday-Feb-15-2017    19 Jumada al-awwal 1438 A.H
# 480  481       Thursday-Feb-16-2017    20 Jumada al-awwal 1438 A.H
# 481  482        Tuesday-Feb-21-2017    25 Jumada al-awwal 1438 A.H
# 482  483    Wednesday-April-05-2017              08 Rajab 1438 A.H
# 483  484         Friday-May-12-2017             15 Shaban 1438 A.H
# 484  485       Saturday-May-20-2017             23 Shaban 1438 A.H
# 485  486        Friday-June-23-2017          27 RamaDHaan 1438 A.H
# 486  487        Monday-July-10-2017            16 SHawwal 1438 A.H
# 487  488        Monday-July-17-2017            22 Shawaal 1438 A.H
# 488  489        Monday-July-17-2017            22 Shawaal 1438 A.H
# 489  490        Monday-July-24-2017            29 Shawaal 1438 A.H
# 490  491    Saturday-August-12-2017             12 Zeqad 1438 A.H.
# 491  492   Thursday-October-05-2017           13 MuHarram 1439 A.H
# 492  493   Thursday-October-19-2017           27 MuHarram 1439 A.H
# 493  494   Thursday-November-9-2017              19 Safar 1439 A.H
# 494  495    Friday-November-24-2017       5 Rabi Al-Awwal 1439 A.H
# 495  496  Saturday-November-25-2017       6 Rabi Al-Awwal 1439 A.H
#
#     Blast Day Type                        Holiday Type                   Time  \
# 0          Holiday                             Weekend                    NaN
# 1      Working Day                                 NaN                    NaN
# 2      Working Day                                 NaN                7:45 AM
# 3      Working Day                                 NaN            11:10:00 AM
# 4      Working Day                                 NaN                    NaN
# 5          Holiday  Christmas/birthday of Quaid-e-Azam  1:40:00 PM/1:42:00 PM
# 6      Working Day                                 NaN                    NaN
# 7      Working Day                                 NaN     1:20:00/1:17:00 PM
# 8      Working Day                                 NaN                evening
# 9      Working Day                                 NaN                    NaN
# 10     Working Day                                 NaN                8:50:PM
# 11     Working Day                                 NaN                7:20 PM
# 12     Working Day                                 NaN        1:27 PM/1:25 PM
# 13         Holiday                             Weekend     5:55:00/6:40:00 PM
# 14     Working Day                                 NaN      11.45PM /10.30 pm
# 15     Working Day                                 NaN                    NaN
# 16     Working Day                                 NaN            11:00:00 AM
# 17     Working Day                                 NaN                evening
# 18         Holiday                              Ashura             9:35:00 AM
# 19     Working Day                                 NaN             9:00:00 AM
# 20         Holiday                   Eid Milad un-Nabi                7.00 pm
# 21     Working Day                                 NaN               10.30 am
# 22     Working Day                                 NaN             3:30:00 PM
# 23         Holiday                             Weekend                8.00 am
# 24     Working Day                                 NaN                 8.30am
# 25     Working Day                                 NaN         7.30 am/7:15AM
# 26         Holiday                             Weekend                    NaN
# 27     Working Day                                 NaN            10:30:00 AM
# 28     Working Day                                 NaN             2:37:00 PM
# 29     Working Day                                 NaN             8:40:00 PM
# ..             ...                                 ...                    ...
# 466    Working Day                                 NaN                    NaN
# 467    Working Day                                 NaN                    NaN
# 468    Working Day                                 NaN                    NaN
# 469    Working Day                                 NaN                5:50 AM
# 470        Holiday                 Eid ul Azha Holiday                7:30 AM
# 471    Working Day                                 NaN                1:30 PM
# 472    Working Day                                 NaN                12:00am
# 473        Weekend                                 NaN                6:00 PM
# 474        Weekend                                 NaN                6:00 AM
# 475    Working Day                                 NaN                5:00 AM
# 476    Working Day                                 NaN                6:00 PM
# 477    Working Day                                 NaN                8:00 AM
# 478    Working Day                                 NaN                3:30 PM
# 479    Working Day                                 NaN                9:00 AM
# 480    Working Day                                 NaN                6:00 PM
# 481    Working Day                                 NaN                9:00 AM
# 482    Working Day                                 NaN                7:15 AM
# 483    Working Day                                 NaN                2:30 PM
# 484        Weekend                                 NaN                    NaN
# 485    Working Day                                 NaN                1:30 PM
# 486    Working Day                                 NaN               11:43 AM
# 487    Working Day                                 NaN                    NaN
# 488    Working Day                                 NaN                    NaN
# 489    Working Day                                 NaN                3:55 PM
# 490        Weekend                                 NaN                5:00 PM
# 491    Working Day                                 NaN                    NaN
# 492    Working Day                                 NaN                8:00 AM
# 493    Working Day                                 NaN                7:00 AM
# 494    Working Day                                 NaN                7:00 AM
# 495    Working Day                                 NaN                7:00 AM
#
#                            City   Latitude   Longitude     Province  ...  \
# 0                     Islamabad  33.718000     73.0718      Capital  ...
# 1                       Karachi  24.991800     66.9911        Sindh  ...
# 2                      Karachi   24.991800     66.9911        Sindh  ...
# 3                       Karachi  24.991800     66.9911        Sindh  ...
# 4                        Quetta  30.209500     67.0182  Baluchistan  ...
# 5                    Rawalpindi  33.605800     73.0437       Punjab  ...
# 6                    Rawalpindi  33.605800     73.0437       Punjab  ...
# 7                      Karachi   24.991800     66.9911        Sindh  ...
# 8                      Karachi   24.991800     66.9911        Sindh  ...
# 9              North waziristan  32.974600     70.1456         FATA  ...
# 10                        Kohat  33.583300     71.4333          KPK  ...
# 11                      Attock   33.764500     72.3667       Punjab  ...
# 12                      Sialkot  32.497200     74.5361       Punjab  ...
# 13                      Lahore   31.545100     74.3407       Punjab  ...
# 14                       Quetta  30.209500     67.0182  Baluchistan  ...
# 15                         Swat  35.222700     72.4258          KPK  ...
# 16                    Islamabad  33.718000     73.0718      Capital  ...
# 17                     Karachi   24.991800     66.9911        Sindh  ...
# 18                        Hangu  33.535100     71.0713          KPK  ...
# 19                      Karachi  24.991800     66.9911        Sindh  ...
# 20                     Karachi   24.991800     66.9911        Sindh  ...
# 21                        Bannu  32.986100     70.6042          KPK  ...
# 22             North Waziristan  32.974600     70.1456         FATA  ...
# 23                      Lasbela  25.837700     66.5224  Baluchistan  ...
# 24                    Malakand   34.503000     71.9046          KPK  ...
# 25                     Peshawar  34.004300     71.5448          KPK  ...
# 26                        Bannu  32.986100     70.6042          KPK  ...
# 27             North Waziristan  32.974600     70.1456         FATA  ...
# 28                    Islamabad  33.718000     73.0718      Capital  ...
# 29                    Peshawar   34.004300     71.5448          KPK  ...
# ..                          ...        ...         ...          ...  ...
# 466                      Mardan  34.207854   72.049453          KPK  ...
# 467                      Mardan  34.195682   72.037771          KPK  ...
# 468                      Quetta  30.194225   67.008822  Balochistan  ...
# 469                      Mardan  34.195776   72.036565          KPK  ...
# 470                   Shikarpur  28.002718   68.730383        Sindh  ...
# 471             Mohmand Agency   34.400331   71.560424         FATA  ...
# 472                      Quetta  30.142830    66.98195  Balochistan  ...
# 473                     Khuzdar  25.776775    67.02239  Balochistan  ...
# 474              Mohmand Agency  34.325826   71.398789         FATA  ...
# 475                       Bannu  32.949814    70.60908          KPK  ...
# 476                      Lahore  31.555382   74.331873       Punjab  ...
# 477  Ghallanai, Mohmand Agency   34.500000   71.333333         FATA  ...
# 478                   Hayatabad  33.986111   71.456944          KPK  ...
# 479   Mosal Kor, Mohmand Agency  34.553808   71.434141         FATA  ...
# 480                 Sehwan town  26.419314   67.859373        Sindh  ...
# 481   Tangi, Charsadda District  34.300000   71.653889          KPK  ...
# 482                      Lahore  31.463017   74.435675       Punjab  ...
# 483                      Quetta  29.800833   66.848056  Baluchistan  ...
# 484                       Kohat  33.387520   71.340408          KPK  ...
# 485                      Quetta  33.884230    70.10878  Balochistan  ...
# 486                      Chaman  30.909830   66.452402  Balochistan  ...
# 487                    Peshawar  34.015000     71.5805          KPK  ...
# 488                    Peshawar  34.015000     71.5805          KPK  ...
# 489                      Lahore  31.500875    74.33312       Punjab  ...
# 490                      Quetta  30.203658   67.004469  Balochistan  ...
# 491                      Quetta  28.571051   67.496895  Balochistan  ...
# 492                      Quetta        NaN         NaN  Balochistan  ...
# 493                      Quetta  30.221057   67.002524  Balochistan  ...
# 494                    Peshawar  33.970623    71.43862          KPK  ...
# 495                      Quetta  30.139626   66.981476  Balochistan  ...
#
#     Targeted Sect if any Killed Min Killed Max Injured Min Injured Max  \
# 0                   None       14.0       15.0         NaN          60
# 1                   None        NaN        3.0         NaN           3
# 2              Christian       13.0       15.0        20.0          40
# 3              Christian        NaN       12.0         NaN          51
# 4                 Shiite       44.0       47.0         NaN          65
# 5                   None       16.0       18.0         NaN          50
# 6                 shiite        NaN        1.0         3.0           4
# 7                 shiite       14.0       15.0        96.0         200
# 8                 Shiite       16.0       18.0         NaN          35
# 9                   None        NaN        2.0         NaN           2
# 10                  None        2.0        3.0         NaN           3
# 11                  None        NaN        7.0        44.0          70
# 12                shiite       25.0       31.0        50.0          75
# 13                shiite        4.0        5.0         6.0          10
# 14                Shiite       25.0       50.0         8.0         100
# 15                  None        NaN        2.0         NaN         NaN
# 16          Shiite/sunni       20.0       25.0        82.0         100
# 17                shiite        5.0        6.0        19.0          30
# 18                Shiite       37.0       40.0        90.0         NaN
# 19             Christian        4.0        5.0        30.0          54
# 20                 Sunni       47.0       57.0         NaN         100
# 21                  None        6.0        7.0         7.0           8
# 22                  None        6.0        7.0         NaN          26
# 23                  None        NaN        1.0         NaN           0
# 24                  None       40.0       42.0        20.0          39
# 25                  None        NaN        1.0         NaN           2
# 26                  None        NaN        1.0         NaN           1
# 27                  None        4.0        5.0        23.0          25
# 28                  None        1.0        2.0         5.0           7
# 29                shiite       13.0       15.0        30.0          60
# ..                   ...        ...        ...         ...         ...
# 466                 None        1.0        1.0        10.0          18
# 467                 None        1.0        1.0        12.0          15
# 468                 None       70.0       70.0       112.0         120
# 469                 None       13.0       14.0        52.0          60
# 470               Shiite        0.0        0.0        10.0          13
# 471                  NaN       16.0       36.0        22.0         NaN
# 472                  NaN       58.0       61.0       100.0         165
# 473                 None       45.0       52.0       100.0         100
# 474                 None        2.0        2.0        14.0          14
# 475                 None        0.0        0.0         2.0           2
# 476                 None       14.0       18.0        83.0          90
# 477                 None        5.0        8.0         0.0           3
# 478                 None        1.0        1.0         4.0          18
# 479                 None        1.0        1.0         0.0           0
# 480               shiite       70.0       72.0       150.0         200
# 481                 None        6.0        7.0        15.0          20
# 482                 None        6.0        7.0        19.0          22
# 483                 None       25.0       28.0        35.0          37
# 484                 None        1.0        4.0         0.0           0
# 485               Shiite       30.0       85.0       100.0        100+
# 486                 None        1.0        3.0         1.0          11
# 487                 None        1.0        2.0         1.0           7
# 488                 None        1.0        1.0         1.0           1
# 489                  NaN       26.0       27.0        56.0          56
# 490                 None       15.0       15.0        40.0          40
# 491                 None       21.0       22.0        25.0         NaN
# 492                 None        7.0        7.0        22.0          22
# 493                 None        2.0        2.0         8.0           8
# 494                 None        1.0        3.0         6.0           8
# 495                 None        4.0        4.0        16.0          22
#
#     No. of Suicide Blasts Explosive Weight (max)  \
# 0                     2.0                    NaN
# 1                     1.0                    NaN
# 2                     1.0                 2.5 Kg
# 3                     1.0                    NaN
# 4                     1.0                    NaN
# 5                     2.0       30kg in each car
# 6                     1.0                    NaN
# 7                     1.0                    2kg
# 8                     1.0                    NaN
# 9                     1.0                    NaN
# 10                    2.0                    NaN
# 11                    1.0                    NaN
# 12                    1.0                    NaN
# 13                    1.0                    NaN
# 14                    1.0                    NaN
# 15                    1.0                    NaN
# 16                    1.0                    NaN
# 17                    1.0                    NaN
# 18                    1.0                    NaN
# 19                    1.0               10-15 kg
# 20                    1.0                   5 kg
# 21                    1.0                    NaN
# 22                    1.0                    NaN
# 23                    1.0                    NaN
# 24                    1.0                    NaN
# 25                    1.0                    NaN
# 26                    1.0                    NaN
# 27                    1.0                    NaN
# 28                    1.0                    NaN
# 29                    1.0                    NaN
# ..                    ...                    ...
# 466                   1.0                 8-10KG
# 467                   1.0                 8-10KG
# 468                   NaN                    8KG
# 469                   1.0                    6KG
# 470                   NaN                    NaN
# 471                   1.0                    NaN
# 472                   2.0                8-10 KG
# 473                   1.0                    NaN
# 474                   4.0                    NaN
# 475                   1.0                  20 KG
# 476                   1.0                    NaN
# 477                   1.0                    NaN
# 478                   1.0                  15 KG
# 479                   1.0                    NaN
# 480                   1.0                    NaN
# 481                   2.0                    NaN
# 482                   NaN                    NaN
# 483                   1.0                    NaN
# 484                   NaN                    NaN
# 485                   3.0                   75KG
# 486                   1.0                    NaN
# 487                   1.0                    NaN
# 488                   1.0                    NaN
# 489                   1.0                    NaN
# 490                   1.0                   25KG
# 491                   1.0                    NaN
# 492                   1.0                    NaN
# 493                   1.0                   15KG
# 494                   1.0                   20KG
# 495                   1.0                   10KG
#
#                                         Hospital Names  Temperature(C)  \
# 0                                                  NaN          15.835
# 1                                                  NaN          23.770
# 2    1.Jinnah Postgraduate Medical Center 2. Civil ...          31.460
# 3                                                  NaN          31.430
# 4    1.CMH Quetta \n2.Civil Hospital 3. Boland Medi...          33.120
# 5                  1.District headquarters \nHospital            9.445
# 6                                                  NaN          15.275
# 7                                      Civil hospital           33.860
# 8    Civil hospital-Liaquat National hospital-Jinna...          31.605
# 9                                                  NaN          27.180
# 10                                           CMH Kohat          32.430
# 11   1.District Headquarters hospital-rwp 2.PIMS Ho...          26.665
# 12   Allama Iqbal Memorial DHQ Hospital-Sardar Begu...          27.510
# 13                                      Mayo Hospital           24.390
# 14                                                 NaN          16.500
# 15                                                 NaN          19.935
# 16   1. PIMS 2.Polyclinic 3.CDA Hospital 4.federal ...          27.160
# 17                           1. Patel Hospital 2. JMPC          31.945
# 18                                     Hangu Hospital           15.495
# 19                                                 NaN          25.300
# 20   1. Liaquat National Hospital 2. Civil Hospital...          28.415
# 21           1. Combined Military 2. Hospital Peshawar          26.125
# 22                                                 NaN          28.610
# 23                                                 NaN          27.500
# 24                      1. CMH Mardan\n2. CMH Peshawar          19.205
# 25                                                 NaN          17.275
# 26                                                 NaN           4.705
# 27                                                 NaN           2.325
# 28                             1.poly Clinic Hospital           16.300
# 29                            1.Lady Reading hospital           15.165
# ..                                                 ...             ...
# 466                                                NaN          23.105
# 467                          Mardan district hospital.          30.020
# 468                                                NaN          29.585
# 469                                                NaN          27.805
# 470                                                NaN          31.945
# 471  District Headquarters Hospital (DHQ) Bajaur Ag...          28.680
# 472                                                NaN          14.545
# 473  Hub, Khuzdar, Lasbella and Civil Hospital in K...             NaN
# 474                                                NaN          17.630
# 475                                 DHQ Hospital Bannu          19.000
# 476        1. Mayo Hospital 2.  Sir Ganga Ram Hospital          16.255
# 477                              Lady Reading Hospital          11.115
# 478                          Hayatabad Medical Complex          16.630
# 479                                                NaN             NaN
# 480  1. Sehwan Taluka Hospital 2. Combined Military...          23.710
# 481                              Lady Reading Hospital          11.180
# 482  Combined Military Hospital (CMH), General Hosp...          29.000
# 483                                                NaN          44.000
# 484                                                NaN          37.000
# 485                                                NaN          36.000
# 486                                                NaN          38.000
# 487                                                NaN          37.000
# 488                                                NaN          37.000
# 489  Jinnah Hospital, General Hospital, Ittefaq Hos...          32.000
# 490                                                NaN          29.000
# 491  Larkana Hospital, Gandawah District Headquarte...          27.800
# 492                                                NaN          26.000
# 493  Combined Military Hospital (CMH)-(Quetta), Civ...          25.000
# 494                Hayatabad Medical Complex(Peshawar)          22.000
# 495                             Civil Hospital(Quetta)          29.000
#
#      Temperature(F)
# 0            60.503
# 1            74.786
# 2            88.628
# 3            88.574
# 4            91.616
# 5            49.001
# 6            59.495
# 7            92.948
# 8            88.889
# 9            80.924
# 10           90.374
# 11           79.997
# 12           81.518
# 13           75.902
# 14           61.700
# 15           67.883
# 16           80.888
# 17           89.501
# 18           59.891
# 19           77.540
# 20           83.147
# 21           79.025
# 22           83.498
# 23           81.500
# 24           66.569
# 25           63.095
# 26           40.469
# 27           36.185
# 28           61.340
# 29           59.297
# ..              ...
# 466          73.589
# 467          86.036
# 468          85.253
# 469          82.049
# 470          89.501
# 471          83.624
# 472          58.181
# 473             NaN
# 474          63.734
# 475             NaN
# 476          61.259
# 477          52.007
# 478          61.934
# 479             NaN
# 480          74.678
# 481          52.124
# 482          84.200
# 483         111.000
# 484          99.000
# 485          97.000
# 486         100.000
# 487          98.000
# 488          98.000
# 489          88.000
# 490             NaN
# 491          81.000
# 492          79.000
# 493          77.000
# 494          72.000
# 495          84.000
#
# [988 rows x 26 columns]

# %%
data.describe()
# Out:
#                S#    Latitude  Killed Min  Killed Max  Injured Min  \
# count  988.000000  983.000000   696.00000  956.000000   726.000000
# mean   247.504049   32.618279    14.79023   15.253138    31.498623
# std    142.684463    2.475619    17.61733   20.288876    38.656426
# min      1.000000   24.879503     0.00000    0.000000     0.000000
# 25%    124.000000   31.823800     3.00000    3.000000     7.000000
# 50%    247.500000   33.583300     8.00000    8.000000    20.000000
# 75%    371.000000   34.004300    20.25000   19.000000    40.000000
# max    496.000000   35.383300   125.00000  148.000000   320.000000
#
#        No. of Suicide Blasts  Temperature(C)  Temperature(F)
# count             824.000000      978.000000      974.000000
# mean                1.116505       21.093650       69.939612
# std                 0.395625        8.375656       15.081500
# min                 1.000000       -2.370000       27.734000
# 25%                 1.000000       14.650000       58.282250
# 50%                 1.000000       21.295000       70.331000
# 75%                 1.000000       28.145000       82.499000
# max                 4.000000       44.000000      111.000000

# %%
data.isnull().any()
# Out:
# S#                         False
# Date                       False
# Islamic Date                True
# Blast Day Type              True
# Holiday Type                True
# Time                        True
# City                       False
# Latitude                    True
# Longitude                   True
# Province                   False
# Location                    True
# Location Category           True
# Location Sensitivity        True
# Open/Closed Space           True
# Influencing Event/Event     True
# Target Type                 True
# Targeted Sect if any        True
# Killed Min                  True
# Killed Max                  True
# Injured Min                 True
# Injured Max                 True
# No. of Suicide Blasts       True
# Explosive Weight (max)      True
# Hospital Names              True
# Temperature(C)              True
# Temperature(F)              True
# dtype: bool

# %%
data['Targeted Sect if any'].unique()
# Out:
# array(['None', 'Christian', 'Shiite', 'shiite', 'Shiite/sunni', 'Sunni',
#        'Jews', nan, 'Ahmedi'], dtype=object)

# %%
# replacing shiite with Shiite and Shiite/sunni with Shiite
data['Targeted Sect if any'].replace(('shiite', 'Shiite/sunni'), ('Shiite', 'Shiite'), inplace  = True)

# %%
data['Targeted Sect if any'].unique()
# Out:
# array(['None', 'Christian', 'Shiite', 'Sunni', 'Jews', nan, 'Ahmedi'],
#       dtype=object)

# %%
size = [697, 96, 76, 18, 2, 2]
colors = ['orange', 'pink', 'crimson', 'purple', 'violet', 'red']
labels= ['None', 'Shiite', 'Sunni', 'Christian', 'Ahmedi', 'Jews']
explode = [0, 0, 0, 0, 1, 2]
my_circle = plt.Circle((0, 0), 0.7, color = 'white')

plt.pie(size, colors = colors, labels = labels,explode = explode, shadow = False, autopct = '%.2f%%')
plt.title('Targeted Sectors by the Terrorists', fontsize = 20)
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
data['Target Type'].value_counts().plot.bar(figsize=(15,6), color='crimson')
plt.xlabel('Targets')
plt.ylabel('Count')
plt.title('Targets set by terrorists')

plt.show()

# %%
data['City'].value_counts().plot.bar(figsize=(20,10), color='crimson')
plt.xlabel('Targets')
plt.ylabel('Count')
plt.title('Targets set by terrorists')

plt.show()

# %%
data['Influencing Event/Event'].value_counts().head(10)
# Out:
# Sectarian strife                                                   14
# Military convoy                                                     8
# Muharram Procession                                                 8
# Shia Religious Gathering                                            4
# military convoy                                                     4
# Sucide bomber wearing an explosive vest carried out the attack.     4
# Army convoy                                                         4
# Military Convoy                                                     4
# Search operation of Security forces                                 4
#  police raid in the area                                            2
# Name: Influencing Event/Event, dtype: int64

# %%
data['Open/Closed Space'].value_counts()
# Out:
# Open           638
# Closed         244
# open            22
# closed          10
# Open             2
# Open/Closed      2
# Name: Open/Closed Space, dtype: int64

# %%
data['Open/Closed Space'].replace(('closed','open','Open/Closed', 'Open '),('Closed', 'Open', 'Open', 'Open'), inplace = True)

# %%
data['Open/Closed Space'].value_counts().plot.pie(colors = ['lightgreen', 'orange'], explode = [0, 0.1])
plt.title('A pie Chart representing choice of terrorists for bombing', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
data['Location Sensitivity'].value_counts()
# Out:
# High      528
# Low       233
# Medium    149
# low         6
# Name: Location Sensitivity, dtype: int64

# %%
#replcaing low with Low
data['Location Sensitivity'].replace('low', 'Low', inplace = True)

# %%
data['Location Sensitivity'].value_counts()
# Out:
# High      528
# Low       239
# Medium    149
# Name: Location Sensitivity, dtype: int64

# %%
data['Location Sensitivity'].value_counts().plot.pie(autopct= '%.2f%%', explode= [0,0,0.2], shadow= True)
plt.title('Location Sensitivity')
plt.legend()
plt.show()

# %%
#Checking different locations category
data['Location Category'].value_counts().plot.bar(figsize=(10,4),color='crimson')
plt.title('Locations Category')
plt.xlabel('Locations Category')
plt.ylabel('Total count')
plt.show()

# %%
data['Location'].value_counts().head(10)
# Out:
# Imambargah                                          6
# Orangi Town Faqeer Colony                           4
# Mingora police Station                              4
# Islamabad Marriott Hotal                            4
# Security check post Miramshah \nNorth Wazirstan     4
# FC fort in Jandola                                  2
# Jamia Masjid Kashmirian in Mochi Gate               2
# Shrine of Bari Imam                                 2
# lakki marwat Police Station                         2
# miranshah Military convoys                          2
# Name: Location, dtype: int64

# %%
data['Longitude'].value_counts().head()
# Out:
# 71.5448    142
# 70.1456     74
# 66.9911     56
# 72.4258     54
# 67.0182     50
# Name: Longitude, dtype: int64

# %%
data['Latitude'].value_counts().head()
# Out:
# 34.0043    142
# 32.9746     74
# 24.9918     56
# 35.2227     54
# 30.2095     50
# Name: Latitude, dtype: int64

# %%
data['Time'].value_counts().head(20)
# Out:
# Evening           24
# 1:30:00 PM        10
# 12:30:00 PM        8
# 6:00 PM            8
# Night              6
# 10:00 AM           6
# Noon               6
# 7:45 AM            6
# evening            6
# 10:30:00 AM        6
# 2:45:00 PM         6
# 9:00 AM            6
# 2:00 PM            6
# 7:15:00 AM         6
# 12:55:00 PM        6
# 8:00 AM            5
# 8:45:00 AM         4
# 11:15:00 AM        4
# 9:20:00 AM         4
# Monday Morning     4
# Name: Time, dtype: int64

# %%
data['Holiday Type'].value_counts(dropna = False)
# Out:
# NaN                                    844
# Weekend                                 90
# Ashura                                   8
# Labour Day                               6
# Eid Milad un-Nabi                        6
# Eid-ul-Fitar                             6
# Ashura Holiday                           4
# Iqbal Day                                4
# Eid Holidays                             4
# Pakistan Day                             4
# Eid-ul-azha                              2
# Christmas/birthday of Quaid-e-Azam       2
# Christmas/ birthday of Quaid-e-Azam      2
# General Elections                        2
# Eid ul Azha Holiday                      2
# Defence Day                              2
# Name: Holiday Type, dtype: int64

# %%
data['Islamic Date'].value_counts().head(15)
# Out:
# 19 Jumada al-awwal 1438 A.H      6
# 5 Rajab 1428 A.H                 6
# 5 Thw al-Hijjah 1431 A.H         4
# 19 SHa`baan 1428 A.H             4
# 25 Thw al-Qi`dah 1430 A.H        4
# 20 Raby` al-THaany 1431 A.H.     4
# 13 Raby` al-THaany 1431 A.H.     4
# 19 Jumaada al-THaany 1430 A.H    4
# 22 SHa`baan 1428 A.H             4
# 8 Thw al-Qi`dah 1429 A.H         4
# 24 RamaDHaan 1431 A.H.           4
# 7 SHawwal 1430 A.H               4
# 7 MuHarram 1431 A.H              4
# 3 Raby` al-awal 1429 A.H         4
# 8 Raby` al-THaany 1430 A.H       4
# Name: Islamic Date, dtype: int64

# %%
# making a pie chart of probability of bombings on type of holidays

size = [801, 156, 10]
labels = ['Working Day', 'Holiday', 'Weekend']
colors = ['lightblue', 'violet', 'magenta']
explode = [0, 0, 0.1]

plt.pie(size, colors = colors, labels = labels, shadow = True, explode = explode, autopct = '%.2f%%')
plt.legend()
plt.show()

# %%
# filling missing values

data['Islamic Date'].fillna('None', inplace = True)
data['Blast Day Type'].fillna(data['Blast Day Type'].mode()[0], inplace = True)
data['Holiday Type'].fillna('None', inplace = True)
data['Time'].fillna(data['Time'].mode()[0], inplace = True) # as it a common value
data['Latitude'].fillna(34.0043, inplace = True) # as it is a common value
data['Longitude'].fillna(71.5448, inplace = True) # as it is most common
data['Location'].fillna(data['Location'].mode()[0], inplace = True)
data['Location Category'].fillna(data['Location Category'].mode()[0], inplace = True)
data['Location Sensitivity'].fillna(data['Location Sensitivity'].mode()[0], inplace = True)
data['Open/Closed Space'].fillna(data['Open/Closed Space'].mode()[0], inplace = True)
data['Influencing Event/Event'].fillna('None', inplace = True)
data['Target Type'].fillna('None', inplace = True)
data['Targeted Sect if any'].fillna('None', inplace = True)
data['Killed Min'].fillna(0, inplace = True)
data['Killed Max'].fillna(1.0, inplace = True)
data['Injured Min'].fillna(data['Injured Min'].mode()[0], inplace = True)
data['Injured Max'].fillna(data['Injured Min'].mode()[0], inplace = True)
data['No. of Suicide Blasts'].fillna(1.0, inplace = True)
data['Explosive Weight (max)'].fillna(data['Explosive Weight (max)'].mode()[0], inplace = True)
data['Hospital Names'].fillna(data['Hospital Names'].mode()[0], inplace = True)
data['Temperature(C)'].fillna(data['Temperature(C)'].mode()[0], inplace = True)
data['Temperature(F)'].fillna(data['Temperature(F)'].mode()[0], inplace = True)

# %%
sns.distplot(data['Injured Min'], color = 'pink')
plt.title('Minimum no. of people injured in a blast', fontsize = 20)
plt.xlabel('Blasts in different days')
plt.ylabel('Count')
plt.show()
# Out:
# E:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data['Explosive Weight (max)'].value_counts().head(15).plot.bar()
plt.title('Most Preferred Explosive Weights in general', fontsize = 15)
plt.xlabel('Explosive Weights')
plt.ylabel('Count')
plt.show()

# %%
data['Province'].value_counts().plot.bar(figsize = (20, 7), color = 'lightblue')
plt.title('Provinces with hhighest number of suicide bombing instances')
plt.xlabel('Province')
plt.ylabel('count')
plt.show()

# %%
data['Location'].value_counts().head(15).plot.bar(figsize = (20, 7), color = 'violet')
plt.title('Top 15 Locations suffering from highest Suicide Bombings', fontsize = 20)
plt.xlabel('Different Locations')
plt.ylabel('No. of Suicide Attacks')
plt.show()

# %%
data1['No. of Suicide Blasts'].value_counts(dropna = False)

labels = ['1', '2', '3', '4']
colors = ['blue', 'lightgreen', 'lightpink', 'magenta']
size = [375, 32, 5, 2]
explode = [0.1, 0.1, 0.2, 0.3]

plt.pie(size, colors = colors, labels = labels, explode = explode, shadow = True)
plt.axis('off')
plt.title('Suicide Blasts Per Day', fontsize = 20)
plt.legend()
plt.show()

# %%
sns.distplot(data['Killed Min'], color = 'yellow')
plt.title('Minimum no. of People Killed in a Suicide Bombing Attack', fontsize = 20)
plt.xlabel('Different Suicide Attacks')
plt.ylabel('count')
plt.show()

# %%
sns.distplot(data['Killed Max'], color = 'orange')
plt.title('Maximum no. of People Killed in a Suicide Bombing Attack', fontsize = 20)
plt.xlabel('Different Suicide Attacks')
plt.ylabel('count')
plt.show()

# %%
data1['Hospital Names'].value_counts().head(10)
# Out:
# Lady Reading Hospital                20
# Lady Reading Hospital \nPeshawar     10
# Lady Reading Hospital                 4
# Lady Reading Hospital (LRH)           3
# Saidu Sharif hospital                 3
# LRH                                   3
# 1.CMH Bannu hospital                  3
# Lady reading hospital                 3
# Civil hospital-CMH                    2
# Lady Reading Hospital Peshwar         2
# Name: Hospital Names, dtype: int64

# %%
x = data['City'].value_counts().nunique()
print("Total no. of different cities where suicide bombing has Occured: ", x)
# Out:
# Total no. of different cities where suicide bombing has Occured:  19

# %%
data1['City'].value_counts().head(15).plot.bar(figsize = (18, 7), color = 'purple')
plt.title('Top 15 Most Preferred Cities for Suicide Bombing', fontsize = 20)
plt.xlabel('Names of Cities')
plt.ylabel('Count')
plt.show()
